# %% [markdown]
# # Quiz 4 — Redes Neuronales para NLP
# ## NLP y Análisis Semántico | Semana 5
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 15 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Las preguntas cubren los temas de la Semana 5: Perceptrones, Retropropagación, MLPs para clasificación de texto, Optimizadores y Regularización.

# %% [markdown]
# ---
# ### Sección A: Perceptrones y Retropropagación (3 puntos)

# %% [markdown]
# **Pregunta 1.** El **perceptrón** original (Rosenblatt, 1958) solo puede clasificar datos que son:
#
# a) Distribuidos normalmente
# b) Linealmente separables
# c) De alta dimensionalidad
# d) No lineales

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** En la **retropropagación** (backpropagation), ¿qué regla del cálculo se utiliza para calcular los gradientes capa por capa?
#
# a) La regla del producto
# b) La regla de la cadena
# c) La regla de L'Hôpital
# d) El teorema de Bayes

# %%
respuesta_2 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 3.** ¿Cuál de las siguientes es una **función de activación** NO lineal comúnmente usada en capas ocultas de redes neuronales modernas?
#
# a) Softmax
# b) ReLU (Rectified Linear Unit)
# c) Sigmoid en la capa de salida
# d) Función identidad f(x) = x

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección B: MLPs y PyTorch (4 puntos)

# %% [markdown]
# **Pregunta 4.** En PyTorch, la función `loss.backward()` calcula:
#
# a) La predicción del modelo para el siguiente batch
# b) Los gradientes de la pérdida respecto a todos los parámetros del modelo
# c) La actualización directa de los pesos del modelo
# d) La pérdida de validación del modelo

# %%
respuesta_4 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 5.** ¿Cuál es el orden correcto del loop de entrenamiento en PyTorch?
#
# a) `loss.backward()` → `optimizer.zero_grad()` → `optimizer.step()`
# b) `optimizer.zero_grad()` → forward pass → `loss.backward()` → `optimizer.step()`
# c) `optimizer.step()` → `loss.backward()` → `optimizer.zero_grad()`
# d) forward pass → `optimizer.step()` → `loss.backward()` → `optimizer.zero_grad()`

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** Para un problema de **clasificación multiclase** (ej: clasificar un texto en 4 categorías), la combinación correcta de capa de salida y función de pérdida en PyTorch es:
#
# a) `nn.Sigmoid()` + `nn.MSELoss()`
# b) `nn.Softmax()` + `nn.NLLLoss()`
# c) Sin activación final + `nn.CrossEntropyLoss()` (que aplica softmax internamente)
# d) `nn.ReLU()` + `nn.CrossEntropyLoss()`

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** Un MLP con la arquitectura `nn.Linear(5000, 256) → ReLU → nn.Linear(256, 4)` tiene aproximadamente cuántos parámetros en total? (incluyendo biases)
#
# a) 5,256
# b) 1,281,284
# c) 5,000 × 256 = 1,280,000
# d) 256 × 4 = 1,024

# %%
respuesta_7 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección C: Optimizadores y Regularización (3 puntos)

# %% [markdown]
# **Pregunta 8.** ¿Cuál es la principal ventaja de **Adam** sobre SGD vanilla?
#
# a) Adam siempre converge al mínimo global
# b) Adam adapta el learning rate por parámetro usando estimaciones del primer y segundo momento del gradiente
# c) Adam no necesita calcular gradientes
# d) Adam funciona sin función de pérdida

# %%
respuesta_8 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 9.** El **Dropout** es una técnica de regularización que durante el entrenamiento:
#
# a) Elimina permanentemente las neuronas con pesos más pequeños
# b) Desactiva neuronas al azar con probabilidad p en cada forward pass, previniendo la co-adaptación
# c) Reduce el learning rate progresivamente
# d) Aumenta el tamaño del batch en cada época

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Dado el siguiente código PyTorch, calcula la cantidad **total de parámetros** (pesos + biases) del modelo:
#
# ```python
# model = nn.Sequential(
#     nn.Linear(300, 128),   # Capa 1
#     nn.ReLU(),
#     nn.Dropout(0.3),
#     nn.Linear(128, 64),    # Capa 2
#     nn.ReLU(),
#     nn.Dropout(0.3),
#     nn.Linear(64, 5),      # Capa de salida
# )
# ```
#
# Recuerda: `nn.Linear(in, out)` tiene `in × out` pesos + `out` biases. `ReLU` y `Dropout` no tienen parámetros.

# %%
# Calcula la cantidad total de parámetros del modelo

# Capa 1: nn.Linear(300, 128)
capa1_pesos = None   # 300 * 128
capa1_biases = None  # 128

# Capa 2: nn.Linear(128, 64)
capa2_pesos = None   # 128 * 64
capa2_biases = None  # 64

# Capa de salida: nn.Linear(64, 5)
salida_pesos = None  # 64 * 5
salida_biases = None # 5

total_parametros = None  # <-- Suma todo aquí

print(f"Total de parámetros: {total_parametros}")

# %% [markdown]
# ---
# ### Entrega
#
# Guarda este notebook y súbelo a la plataforma del curso.
#
# **Nombre:** *(escribe tu nombre aquí)*
# **Fecha:** *(escribe la fecha aquí)*
