# %% [markdown]
# # Quiz 1 — Evaluación Diagnóstica
# ## NLP y Análisis Semántico | Semana 1
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 10 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Este quiz es **diagnóstico**: ayuda a identificar tu nivel de conocimientos previos.
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Si no sabes la respuesta, escribe `"No sé"` — ¡está bien! Para eso es diagnóstico.

# %% [markdown]
# ---
# ### Sección A: Python Básico (4 puntos)

# %% [markdown]
# **Pregunta 1.** ¿Cuál es el resultado de la siguiente expresión?
#
# ```python
# texto = "Hola Mundo"
# print(texto.lower().split())
# ```
#
# a) `"hola mundo"`
# b) `["hola", "mundo"]`
# c) `["Hola", "Mundo"]`
# d) `"holamundo"`

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** Dada la siguiente lista:
#
# ```python
# palabras = ["gato", "perro", "ave", "pez", "gato", "ave", "gato"]
# ```
#
# Escribe **una línea de código** que cuente cuántas veces aparece cada palabra.
# *(Pista: puedes usar una estructura de datos de Python o una librería.)*

# %%
palabras = ["gato", "perro", "ave", "pez", "gato", "ave", "gato"]

conteo = None  # <-- Escribe tu código aquí

print(conteo)

# %% [markdown]
# **Pregunta 3.** ¿Qué hace la siguiente list comprehension?
#
# ```python
# [x for x in range(10) if x % 2 == 0]
# ```
#
# a) Genera los números del 0 al 10
# b) Genera los números impares del 0 al 9
# c) Genera los números pares del 0 al 9
# d) Genera un error

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 4.** Escribe una función que reciba una cadena de texto y devuelva un **diccionario** donde las llaves sean las palabras y los valores la longitud de cada palabra.
#
# Ejemplo: `"hola mundo"` → `{"hola": 4, "mundo": 5}`

# %%
def longitud_palabras(texto):
    pass  # <-- Escribe tu código aquí

# Prueba
print(longitud_palabras("hola mundo"))  # Esperado: {'hola': 4, 'mundo': 5}

# %% [markdown]
# ---
# ### Sección B: Matemáticas y Estadística (3 puntos)

# %% [markdown]
# **Pregunta 5.** Si tengo dos vectores $\vec{a} = [1, 2, 3]$ y $\vec{b} = [4, 5, 6]$, ¿cuál es su **producto punto** (dot product)?
#
# a) $[4, 10, 18]$
# b) $32$
# c) $[5, 7, 9]$
# d) $15$

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** Si lanzo una moneda justa 3 veces, ¿cuál es la probabilidad de obtener exactamente 2 caras?
#
# a) $1/2$
# b) $1/4$
# c) $3/8$
# d) $1/8$

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** ¿Qué función de activación transforma cualquier valor real en un número entre 0 y 1?
#
# a) ReLU
# b) Softmax
# c) Sigmoid
# d) Tanh

# %%
respuesta_7 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección C: Conceptos Generales de IA/ML (3 puntos)

# %% [markdown]
# **Pregunta 8.** ¿Cuál es la diferencia principal entre **aprendizaje supervisado** y **no supervisado**? Responde en 1-2 oraciones.

# %%
respuesta_8 = ""  # Escribe tu respuesta como texto

# %% [markdown]
# **Pregunta 9.** En un problema de **clasificación binaria**, tenemos 90 muestras positivas y 10 negativas. Si un modelo predice SIEMPRE "positivo", ¿cuál sería su *accuracy* (exactitud)?
#
# a) 50%
# b) 90%
# c) 100%
# d) 10%

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Menciona **2 aplicaciones** del Procesamiento de Lenguaje Natural que uses en tu vida diaria.

# %%
respuesta_10 = ""  # Escribe tu respuesta como texto

# %% [markdown]
# ---
# ### Entrega
#
# Guarda este notebook y súbelo a la plataforma del curso.
#
# **Nombre:** *(escribe tu nombre aquí)*
# **Fecha:** *(escribe la fecha aquí)*
