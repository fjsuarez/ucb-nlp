# %% [markdown]
# # Quiz 5 — RNNs, LSTM y GRU
# ## NLP y Análisis Semántico | Semana 6
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 15 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Las preguntas cubren los temas de la Semana 6: Arquitectura RNN, LSTM, GRU y RNNs Bidireccionales.

# %% [markdown]
# ---
# ### Sección A: Arquitectura RNN (3 puntos)

# %% [markdown]
# **Pregunta 1.** La ecuación del estado oculto de una RNN simple es $h_t = \tanh(W_{xh} x_t + W_{hh} h_{t-1} + b_h)$. ¿Qué papel cumple el término $W_{hh} h_{t-1}$?
#
# a) Proyecta la entrada actual a un espacio de mayor dimensión
# b) Transfiere información de pasos anteriores al paso actual
# c) Normaliza los gradientes durante la retropropagación
# d) Aplica regularización L2 a los pesos

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** En PyTorch, cuando usamos `nn.utils.rnn.pack_padded_sequence` antes de pasar datos a una RNN, el objetivo principal es:
#
# a) Aumentar la velocidad de cómputo al paralelizar las secuencias
# b) Evitar que la RNN procese tokens de padding como si fueran datos reales
# c) Convertir las secuencias a embeddings de dimensión fija
# d) Aplicar dropout entre las capas de la RNN

# %%
respuesta_2 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 3.** El problema del **gradiente que se desvanece** (vanishing gradient) en RNNs se produce porque durante BPTT:
#
# a) La función softmax satura los gradientes en la capa de salida
# b) El gradiente se multiplica repetidamente por $W_{hh}$ y $\tanh'$, reduciendo su magnitud exponencialmente
# c) El learning rate es demasiado pequeño para secuencias largas
# d) Las capas de embedding no reciben gradientes

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección B: LSTM (4 puntos)

# %% [markdown]
# **Pregunta 4.** La diferencia fundamental entre una RNN simple y una LSTM es que la LSTM:
#
# a) Usa funciones de activación ReLU en lugar de tanh
# b) Introduce una celda de memoria $c_t$ con actualización aditiva que preserva los gradientes
# c) Tiene más capas ocultas que la RNN
# d) Procesa las secuencias en ambas direcciones

# %%
respuesta_4 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 5.** La **compuerta de olvido** (forget gate) de la LSTM calcula $f_t = \sigma(W_f [h_{t-1}, x_t] + b_f)$. Si $f_t \approx 0$ para todas las dimensiones, ¿qué sucede?
#
# a) La celda de memoria mantiene toda la información anterior
# b) El estado oculto $h_t$ se vuelve cero
# c) La celda de memoria borra la información anterior y solo retiene información nueva
# d) La LSTM se comporta como una RNN simple

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** En PyTorch, `nn.LSTM(input_size=100, hidden_size=256, batch_first=True)` aplicado a un tensor de forma `(32, 20, 100)`. ¿Cuál es la forma del tensor `output`?
#
# a) `(32, 256)`
# b) `(32, 20, 256)`
# c) `(32, 20, 512)`
# d) `(1, 32, 256)`

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** Una LSTM con `input_size=d` y `hidden_size=D` tiene aproximadamente $4 \times D(d + D + 1)$ parámetros. El factor 4 se debe a:
#
# a) Las 4 capas ocultas de la red
# b) Las 4 direcciones de procesamiento
# c) Las 3 compuertas (forget, input, output) más el candidato de celda $\tilde{c}_t$
# d) Los 4 estados internos del modelo

# %%
respuesta_7 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección C: GRU y RNNs Bidireccionales (3 puntos)

# %% [markdown]
# **Pregunta 8.** ¿Cuál es una diferencia clave entre la GRU y la LSTM?
#
# a) La GRU tiene 4 compuertas mientras que la LSTM tiene 2
# b) La GRU combina el estado oculto y la celda de memoria en un solo estado $h_t$, usando 2 compuertas en vez de 3
# c) La GRU no puede capturar dependencias de largo plazo
# d) La GRU siempre tiene mejor rendimiento que la LSTM

# %%
respuesta_8 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 9.** En una RNN bidireccional, el estado oculto final para cada token $t$ se obtiene:
#
# a) Promediando los estados forward y backward
# b) Concatenando el estado forward $\overrightarrow{h}_t$ y el estado backward $\overleftarrow{h}_t$
# c) Multiplicando los estados forward y backward
# d) Usando solo el estado forward (el backward se descarta)

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Si usamos `nn.GRU(input_size=100, hidden_size=128, bidirectional=True, batch_first=True)` con un tensor de entrada `(16, 30, 100)`, ¿cuál es la dimensión del tensor `output`?
#
# a) `(16, 30, 128)`
# b) `(16, 30, 256)`
# c) `(2, 16, 128)`
# d) `(16, 60, 128)`

# %%
respuesta_10 = ""  # Escribe a, b, c o d

# %% [markdown]
# # Quiz 5 — Redes Neuronales Recurrentes
# ## NLP y Análisis Semántico | Semana 6
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 15 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Las preguntas cubren los temas de la Semana 6: Arquitectura RNN, LSTM, GRU y RNNs Bidireccionales.

# %% [markdown]
# ---
# ### Sección A: Arquitectura RNN (3 puntos)

# %% [markdown]
# **Pregunta 1.** En una RNN, el estado oculto $h_t$ se calcula como:
#
# a) $h_t = \sigma(W_x x_t + b)$ (solo depende de la entrada actual)
# b) $h_t = \tanh(W_{xh} x_t + W_{hh} h_{t-1} + b)$ (combina entrada actual y estado anterior)
# c) $h_t = W_{xh} x_t \cdot W_{hh} h_{t-1}$ (producto de matrices)
# d) $h_t = \text{softmax}(W x_t + h_{t-1})$ (normalización probabilística)

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** ¿Cuál es el propósito principal de `pack_padded_sequence` en PyTorch al trabajar con secuencias de longitud variable?
#
# a) Aumenta la longitud de todas las secuencias al máximo
# b) Permite que la RNN ignore los tokens de padding, evitando cómputos innecesarios y gradientes incorrectos
# c) Convierte las secuencias en vectores de longitud fija
# d) Ordena las secuencias alfabéticamente

# %%
respuesta_2 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 3.** El problema del **gradiente que desaparece** (vanishing gradient) en RNNs simples ocurre porque:
#
# a) El learning rate es demasiado grande
# b) Durante BPTT, el gradiente se multiplica repetidamente por $W_{hh}$ y $\tanh'$, y si el producto tiene eigenvalores $< 1$, el gradiente se reduce exponencialmente
# c) La función softmax siempre produce valores cercanos a 0
# d) PyTorch no puede calcular gradientes para secuencias largas

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección B: LSTM (4 puntos)

# %% [markdown]
# **Pregunta 4.** La LSTM resuelve el vanishing gradient principalmente gracias a:
#
# a) Usar activaciones ReLU en lugar de tanh
# b) La celda de memoria $c_t$ que se actualiza de forma **aditiva** ($c_t = f_t \odot c_{t-1} + i_t \odot \tilde{c}_t$), permitiendo que los gradientes fluyan sin multiplicaciones repetidas
# c) Usar un learning rate adaptativo automáticamente
# d) Reducir el número de parámetros del modelo

# %%
respuesta_4 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 5.** En una LSTM, la **compuerta de olvido** (forget gate) $f_t$ controla:
#
# a) Qué información nueva se añade a la celda de memoria
# b) Qué parte del estado oculto se expone como salida
# c) Qué proporción de la celda de memoria anterior $c_{t-1}$ se **mantiene** en el paso actual
# d) La tasa de aprendizaje del optimizador

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** En PyTorch, `nn.LSTM` con `batch_first=True` retorna `output, (h_n, c_n)`. ¿Qué contiene `output`?
#
# a) Solo el estado oculto del último paso temporal
# b) Los estados ocultos $h_t$ de **todos** los pasos temporales: `(batch, seq_len, hidden_dim)`
# c) Las predicciones finales del modelo (logits)
# d) Los gradientes calculados por backpropagation

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** Una LSTM tiene **3 compuertas** (forget, input, output) mientras que una RNN simple tiene **0 compuertas**. Si `hidden_dim = D` y la dimensión de entrada es `d`, ¿cuántos parámetros tiene una capa LSTM aproximadamente (sin contar biases)?
#
# a) $D(d + D)$ — lo mismo que una RNN
# b) $2 \times D(d + D)$ — el doble de una RNN
# c) $4 \times D(d + D)$ — cuatro veces una RNN (3 compuertas + candidato)
# d) $3 \times D(d + D)$ — tres veces una RNN

# %%
respuesta_7 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección C: GRU y RNNs Bidireccionales (3 puntos)

# %% [markdown]
# **Pregunta 8.** La GRU (Gated Recurrent Unit) se diferencia de la LSTM en que:
#
# a) La GRU tiene 4 compuertas mientras que la LSTM tiene 3
# b) La GRU combina las compuertas de olvido e input en una sola compuerta de **actualización** $z_t$, y no tiene celda de memoria separada
# c) La GRU no puede procesar secuencias de longitud variable
# d) La GRU siempre tiene mejor rendimiento que la LSTM

# %%
respuesta_8 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 9.** En una RNN **bidireccional**, el estado oculto final para clasificación se obtiene típicamente como:
#
# a) Solo el estado oculto de la dirección forward $\overrightarrow{h}_T$
# b) La concatenación de los estados finales forward y backward: $[\overrightarrow{h}_T ; \overleftarrow{h}_1]$
# c) El promedio de todos los estados ocultos de ambas direcciones
# d) La suma de las dos direcciones dividida por 2

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Dado el siguiente modelo en PyTorch, ¿cuál es la dimensión de `output` y `h_n`?
#
# ```python
# rnn = nn.GRU(input_size=50, hidden_size=128, num_layers=2,
#              batch_first=True, bidirectional=True)
# x = torch.randn(16, 20, 50)  # batch=16, seq_len=20, input=50
# output, h_n = rnn(x)
# ```
#
# a) `output`: (16, 20, 128), `h_n`: (2, 16, 128)
# b) `output`: (16, 20, 256), `h_n`: (4, 16, 128)
# c) `output`: (16, 20, 256), `h_n`: (2, 16, 256)
# d) `output`: (16, 20, 128), `h_n`: (4, 16, 256)

# %%
respuesta_10 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Entrega
#
# Guarda este notebook y súbelo a la plataforma del curso.
#
# **Nombre:** *(escribe tu nombre aquí)*
# **Fecha:** *(escribe la fecha aquí)*
