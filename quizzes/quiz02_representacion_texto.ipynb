# %% [markdown]
# # Quiz 2 — Representación de Texto
# ## NLP y Análisis Semántico | Semana 2
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 15 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Las preguntas cubren los temas de la Semana 2: BoW, One-hot, TF-IDF, PMI y N-gramas.

# %% [markdown]
# ---
# ### Sección A: Bolsa de Palabras y One-hot (3 puntos)

# %% [markdown]
# **Pregunta 1.** Dado el siguiente corpus:
#
# ```
# D1: "el gato come pescado"
# D2: "el perro come carne"
# ```
#
# ¿Cuál es el vector BoW del documento D1 si el vocabulario ordenado es `[carne, come, el, gato, perro, pescado]`?
#
# a) `[1, 1, 1, 1, 1, 1]`
# b) `[0, 1, 1, 1, 0, 1]`
# c) `[1, 1, 1, 0, 0, 1]`
# d) `[0, 1, 1, 1, 1, 0]`

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** ¿Cuál es la principal **limitación** de la representación One-hot encoding?
#
# a) No puede representar palabras fuera del vocabulario
# b) Todos los vectores son ortogonales — no captura similitud semántica entre palabras
# c) Los vectores son demasiado pequeños para ser útiles
# d) Requiere un corpus de entrenamiento muy grande

# %%
respuesta_2 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 3.** Si un vocabulario tiene 5,000 palabras, ¿cuál es la dimensionalidad de cada vector One-hot?
#
# a) 1
# b) 100
# c) 5,000
# d) Depende de la longitud del documento

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección B: TF-IDF (4 puntos)

# %% [markdown]
# **Pregunta 4.** ¿Qué mide el componente **IDF** (Inverse Document Frequency) de TF-IDF?
#
# a) Cuántas veces aparece un término en un documento
# b) Qué tan raro o informativo es un término en el corpus
# c) La longitud promedio de los documentos
# d) La frecuencia total de un término en todo el corpus

# %%
respuesta_4 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 5.** Dado un corpus de 100 documentos, la palabra "gato" aparece en 10 documentos. ¿Cuál es su IDF usando IDF(t) = log10(N / df_t)?
#
# a) log10(10) = 1
# b) log10(100) = 2
# c) log10(0.1) = -1
# d) log10(1000) = 3

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** Si una palabra aparece en **todos** los documentos del corpus, su valor IDF es:
#
# a) Muy alto (la palabra es muy importante)
# b) 1 (valor neutral)
# c) 0 (la palabra no es informativa)
# d) Negativo (penaliza la palabra)

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** Escribe código Python que calcule el valor **TF-IDF** del término "nlp" en el documento D1, dado:
#
# - D1 = "nlp es procesamiento de lenguaje natural nlp"
# - El corpus tiene 50 documentos en total
# - "nlp" aparece en 5 documentos del corpus
#
# Usa: TF-IDF(t,d) = TF(t,d) x IDF(t), donde TF(t,d) = f_td / total_terminos_en_d y IDF(t) = log10(N / df_t).

# %%
import math

D1 = "nlp es procesamiento de lenguaje natural nlp"
N = 50      # Total de documentos en el corpus
df_nlp = 5  # Documentos que contienen "nlp"

tf = None   # <-- Calcula TF aquí
idf = None  # <-- Calcula IDF aquí
tfidf = None  # <-- Calcula TF-IDF aquí

print(f"TF = {tf}")
print(f"IDF = {idf}")
print(f"TF-IDF = {tfidf}")

# %% [markdown]
# ---
# ### Sección C: PMI y N-gramas (3 puntos)

# %% [markdown]
# **Pregunta 8.** La Información Mutua Puntual (PMI) entre dos palabras x e y se define como:
#
# PMI(x, y) = log2( P(x, y) / (P(x) * P(y)) )
#
# Si dos palabras son **completamente independientes**, ¿cuál es su PMI?
#
# a) Un valor positivo alto
# b) Un valor negativo
# c) 0
# d) Indefinido

# %%
respuesta_8 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 9.** ¿Cuál de las siguientes secuencias es un **trigrama** (3-grama) de la oración "el gato come pescado fresco"?
#
# a) ("el", "gato")
# b) ("gato", "come", "pescado")
# c) ("el", "come", "fresco")
# d) ("el", "gato", "come", "pescado")

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Escribe código Python que extraiga todos los **bigramas** de la siguiente oración y los imprima como una lista de tuplas.
#
# Ejemplo de salida esperada: [("el", "gato"), ("gato", "come"), ...]

# %%
oracion = "el procesamiento de lenguaje natural es fascinante"

bigramas = None  # <-- Escribe tu código aquí

print(bigramas)

# %% [markdown]
# ---
# ### Entrega
#
# Guarda este notebook y súbelo a la plataforma del curso.
#
# **Nombre:** *(escribe tu nombre aquí)*
# **Fecha:** *(escribe la fecha aquí)*
