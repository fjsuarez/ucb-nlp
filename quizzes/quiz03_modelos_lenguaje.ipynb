# %% [markdown]
# # Quiz 3 — Modelos de Lenguaje y Etiquetado POS
# ## NLP y Análisis Semántico | Semana 3
#
# **Prof.:** Francisco Suárez
# **Tiempo estimado:** 15 minutos
# **Puntos:** 10 (1 punto por pregunta)
#
# ---
#
# **Instrucciones:**
# - Responde directamente en las celdas de código indicadas.
# - No uses herramientas de IA para este quiz.
# - Las preguntas cubren los temas de la Semana 3: Modelos N-gram, Perplejidad, Suavizado, HMM y Etiquetado POS.

# %% [markdown]
# ---
# ### Sección A: Modelos de Lenguaje N-gram (3 puntos)

# %% [markdown]
# **Pregunta 1.** El **supuesto de Markov** en un modelo de lenguaje bigrama establece que:
#
# a) La probabilidad de una palabra depende de todas las palabras anteriores en la oración
# b) La probabilidad de una palabra depende solo de la palabra inmediatamente anterior
# c) Todas las palabras de la oración son independientes entre sí
# d) La probabilidad de una palabra depende de las dos palabras anteriores

# %%
respuesta_1 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 2.** Dado el siguiente corpus de entrenamiento:
#
# ```
# "el gato come pescado . el gato bebe leche ."
# ```
#
# ¿Cuál es la probabilidad bigrama P(come | gato)?
#
# a) 1/1 = 1.0
# b) 2/2 = 1.0
# c) 1/2 = 0.5
# d) 1/10 = 0.1

# %%
respuesta_2 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 3.** ¿Cuál es la fórmula correcta para la probabilidad de un **trigrama**?
#
# a) P(w_i) = C(w_i) / N
# b) P(w_i | w_{i-1}) = C(w_{i-1}, w_i) / C(w_{i-1})
# c) P(w_i | w_{i-2}, w_{i-1}) = C(w_{i-2}, w_{i-1}, w_i) / C(w_{i-2}, w_{i-1})
# d) P(w_i | w_{i-3}, w_{i-2}, w_{i-1}) = C(w_{i-3}, w_{i-2}, w_{i-1}, w_i) / C(w_{i-3}, w_{i-2}, w_{i-1})

# %%
respuesta_3 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección B: Perplejidad y Suavizado (4 puntos)

# %% [markdown]
# **Pregunta 4.** La **perplejidad** de un modelo de lenguaje mide:
#
# a) El número total de palabras en el vocabulario
# b) Qué tan "sorprendido" está el modelo al ver el texto de prueba — menor perplejidad indica mejor modelo
# c) La cantidad de parámetros del modelo
# d) El tiempo de entrenamiento del modelo

# %%
respuesta_4 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 5.** ¿Qué sucede con la perplejidad cuando un modelo de lenguaje (sin suavizado) encuentra un bigrama **nunca visto** en los datos de entrenamiento?
#
# a) La perplejidad se vuelve 0
# b) La perplejidad se vuelve infinita porque P = 0 y log(0) es indefinido
# c) La perplejidad no cambia
# d) La perplejidad se vuelve 1

# %%
respuesta_5 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 6.** El **suavizado de Laplace** (Add-1) consiste en:
#
# a) Multiplicar todas las probabilidades por un factor constante
# b) Sumar 1 al conteo de cada n-grama y ajustar el denominador con el tamaño del vocabulario V
# c) Eliminar los n-gramas con conteo cero del vocabulario
# d) Interpolar entre modelos de diferente orden

# %%
respuesta_6 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 7.** Dado un modelo bigrama con suavizado Laplace (Add-1), un vocabulario de tamaño V = 1000, y C(gato) = 50. ¿Cuál es la probabilidad suavizada P_Laplace(come | gato) si el bigrama ("gato", "come") **nunca** apareció en el corpus?
#
# Usa la fórmula: P_Laplace(w_i | w_{i-1}) = (C(w_{i-1}, w_i) + 1) / (C(w_{i-1}) + V)
#
# a) 0/50 = 0
# b) 1/1050 ≈ 0.00095
# c) 1/50 = 0.02
# d) 1/1000 = 0.001

# %%
respuesta_7 = ""  # Escribe a, b, c o d

# %% [markdown]
# ---
# ### Sección C: HMM y Etiquetado POS (3 puntos)

# %% [markdown]
# **Pregunta 8.** Un Modelo Oculto de Markov (HMM) para etiquetado POS tiene dos tipos de probabilidades. Las **probabilidades de emisión** P(w_i | t_i) representan:
#
# a) La probabilidad de pasar de una etiqueta POS a otra
# b) La probabilidad de que una etiqueta POS genere (emita) una palabra específica
# c) La probabilidad de que una palabra aparezca al inicio de una oración
# d) La probabilidad conjunta de toda la secuencia de palabras

# %%
respuesta_8 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 9.** El **algoritmo de Viterbi** se utiliza para:
#
# a) Entrenar las probabilidades de un HMM a partir de un corpus
# b) Encontrar la secuencia de etiquetas POS más probable para una oración dada
# c) Calcular la perplejidad de un modelo de lenguaje
# d) Generar texto nuevo a partir de un modelo de lenguaje

# %%
respuesta_9 = ""  # Escribe a, b, c o d

# %% [markdown]
# **Pregunta 10.** Dado un HMM con los siguientes parámetros simplificados:
#
# - Estados (etiquetas): {DET, NOUN, VERB}
# - Probabilidades de transición: P(NOUN | DET) = 0.8, P(VERB | NOUN) = 0.6
# - Probabilidades de emisión: P("el" | DET) = 0.5, P("gato" | NOUN) = 0.3, P("come" | VERB) = 0.4
# - Probabilidades iniciales: P_0(DET) = 0.6
#
# Calcula la probabilidad del camino DET → NOUN → VERB para la oración "el gato come" usando:
#
# P = P_0(DET) × P("el" | DET) × P(NOUN | DET) × P("gato" | NOUN) × P(VERB | NOUN) × P("come" | VERB)

# %%
# Calcula la probabilidad del camino DET -> NOUN -> VERB
# para la oración "el gato come"

p0_DET = 0.6
p_el_DET = 0.5
p_NOUN_DET = 0.8
p_gato_NOUN = 0.3
p_VERB_NOUN = 0.6
p_come_VERB = 0.4

probabilidad = None  # <-- Calcula el producto aquí

print(f"P(DET→NOUN→VERB, 'el gato come') = {probabilidad}")

# %% [markdown]
# ---
# ### Entrega
#
# Guarda este notebook y súbelo a la plataforma del curso.
#
# **Nombre:** *(escribe tu nombre aquí)*
# **Fecha:** *(escribe la fecha aquí)*
